# %%
import pandas as pd

# %%
df = pd.read_csv("NYCHAContracts.csv")
df
# Out:
#        Contract Number                                        Description  \
# 0              2330498  JOHNSON COMMUNITY CENTER - BATHROOM UPGRADES (...
# 1              2413656  Special Repair Projects - Morrisania Houses Fi...
# 2              2333979  EVP Legal Affairs & General Counsel - Online L...
# 3              2404448  Paint Admin- IDIQ Contract for Maint. Painting...
# 4              2413667  Special Repair Projects - Soundview Houses Fir...
# ...                ...                                                ...
# 10566          1100005  Clinton- Maintenance Painting of Apartments (M...
# 10567          1100010  Var BK-Maintenance Painting of Apts (BK Mgmt_T...
# 10568          1100001  Sedgwick-V/C Floor Tile In Apartments (BX Mgmt...
# 10569          1100003  Harlem River-V/C Floor Tile In Apartments (MX ...
# 10570          1100004  Var.-Maintenance Painting of Apartments (MX Mg...
#
#       Start Date   End Date                                Vendor Name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10571 entries, 0 to 10570
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Contract Number     10571 non-null  int64
#  1   Description         10571 non-null  object
#  2   Start Date          10571 non-null  object
#  3   End Date            10571 non-null  object
#  4   Vendor Name         10571 non-null  object
#  5   Total Amount        10571 non-null  object
#  6   Amount Spent        10571 non-null  object
#  7   Procurement Method  10571 non-null  object
#  8   Trade Type          10571 non-null  object
#  9   Category            10571 non-null  object
#  10  Location            10571 non-null  object
#  11  Contract Status     10571 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 991.2+ KB

# %%
df["Category"].unique()
# Out:
# array(['GR-GENERAL RENOVATION TYPE A.1CM',
#        'PS-PROFESSIONAL SERVICES OTHER.1CM', 'PD-PAINTING.1CM',
#        'AS-ASBESTOS ABATEMENT.1CM', 'RF-ROOF.1CM',
#        'SP-GUARD SERVICE.FIRE WATCH SERVICE', 'PLUMBING CMA.PLUMBING CMA',
#        'CARPENTRY TRADE.WINDOWS', 'BL-BOILER REPLACEMENT.1CM',
#        'TL-TILE.1CM', 'PLUMBING AND HEATING.FIXTURES', 'CA-CARTING.1CM',
#        'FUELS AND LUBRICANTS.LUBRICANTS', 'PL-PLUMBING.1CM',
#        'HE-TRAINING.1CM', 'RESTRICTED.INSECTICIDES',
#        'TOOLS.MISCELLANEOUS', 'MACHINERY.MACHINES - FLOOR POLISHING',
#        'AR-AFFORDABILITY & RENTAL ASSISTANCE.1CM',
#        'SM-SMALL PURCHASE.RENTAL', 'RE-RENT.1CM',
#        'IT-MAINTENANCE CONTRACTS.1CM', 'ST-STRUCTURAL.1CM',
#        'PG-POSTAGE.1CM', 'TEXTILES.CLOTHES - MAINT WORKCLOTHES',
#        'HARDWARE.HARDWARE - DOOR', 'JA-JANITORIAL.1CM', 'CP-COMPUTER.1CM',
#        'AUTOMOTIVE.PARTS AND ACCESSORIES', 'EV-ELEVATOR.1CM',
# ...

# %%
df.query('Category == "EX-EXTERMINATING SERVICES.1CM"')
# Out:
#       Contract Number                                        Description  \
# 1232          2200461  Pest Control-IDIQ Contract for Integrated Pest...
# 1242          2200462  Pest Control- Integrated Pest Management at Va...
# 1288          2200460  Pest Control Department - IDIQ Integrated Pest...
# 1428          2122865  Pest Control- IDIQ Integrated Pest Management ...
# 1429          2122866  SMD IDIQ Integrated Pest Management - Various ...
# 1430          2122405  Pest Control- IDIQ Integrated Pest Management ...
# 1432          2122359  Pest Control- IDIQ Contract for Integrated Pes...
# 1777          2122030  VP OPERATIONS EMERGENCY IDIQ CONTRACT FOR EXTE...
# 1778          2122031  VP OPERATIONS EMERGENCY IDIQ CONTRACT FOR EXTE...
# 1779          2122033  VP OPERATIONS EMERGENCY IDIQ CONTRACT FOR EXTE...
# 1780          2122035  VP OPERATIONS EMERGENCY IDIQ CONTRACT FOR EXTE...
# 1802          2117361  Various Developments in All Five (5) Boroughs ...
# ...

# %%
df.query('Category == "EX-EXTERMINATING SERVICES.EXTERMINATION"')
# Out:
#       Contract Number                                        Description  \
# 607           2301396  Pest Management - Mosquito Control - Catch Bas...
# 5060          1613963  VARIOUS BRONX - APPLICATION OF LARVICIDE IN CA...
# 5061          1613967  VARIOUS BROOKLYN - APPLICATION OF LARVICIDE IN...
# 5062          1613969  VARIOUS MANHATTAN - APPLICATION OF LARVICIDE I...
#
#      Start Date    End Date                               Vendor Name  \
# 607    3/2/2023    3/1/2026                    PEST TERMINATORS, INC.
# 5060   6/1/2016  12/31/2016         DIAL-A-BUG PEST CONTROL OF NY INC
# 5061   6/1/2016  12/31/2016          KINGSWAY EXTERMINATING CO., INC.
# 5062   6/1/2016  12/31/2016  U.S.A. EXTERMINATORS & PEST CONTROL INC.
#
#      Total Amount Amount Spent Procurement Method Trade Type  \
# 607   $216,000.00   $70,260.00         SEALED BID    Service
# 5060   $13,574.58   $13,574.58     SMALL PURCHASE    Service
# 5061   $20,064.65   $19,105.55     SMALL PURCHASE    Service
# ...

# %%
df.query('Category == "SM-SMALL PURCHASE.EXTERMINATOR"')
# Out:
#       Contract Number                                        Description  \
# 2771          1922949  Various Citywide Developments - Mosquito Contr...
# 3670          1819680  VARIOUS BRONX - MOSQUITO CONTROL - CATCH BASIN...
# 3672          1819685  VARIOUS QUEENS & STATEN ISLAND - MOSQUITO CONT...
# 3726          1819682  VARIOUS MANHATTAN - MOSQUITO CONTROL - CATCH B...
# 3727          1819683  VARIOUS BROOKLYN - MOSQUITO CONTROL - CATCH BA...
#
#      Start Date    End Date                               Vendor Name  \
# 2771  9/23/2019  11/17/2022         DIAL-A-BUG PEST CONTROL OF NY INC
# 3670   8/1/2018   7/31/2019  U.S.A. EXTERMINATORS & PEST CONTROL INC.
# 3672  7/31/2018   7/30/2019  U.S.A. EXTERMINATORS & PEST CONTROL INC.
# 3726   7/9/2018   5/15/2021         DIAL-A-BUG PEST CONTROL OF NY INC
# 3727   7/9/2018   7/20/2020         DIAL-A-BUG PEST CONTROL OF NY INC
#
#      Total Amount Amount Spent Procurement Method Trade Type  \
# ...
